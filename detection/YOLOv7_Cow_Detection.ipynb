# %% [markdown]
# <a href="https://colab.research.google.com/github/gnozadi/Cow-detection-segmentation/blob/main/detection/YOLOv7_Cow_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download YOLOv7 repository and install requirements
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !pip install -r requirements.txt

# %%
# %cd /content/yolov7
# !python train.py --batch 16 --epochs 55 --data /content/drive/MyDrive/cow-dataset-6/datav6.yaml --weights 'yolov7.pt' --device 0
# Out:
# /content/yolov7
# 2023-08-30 06:02:41.183389: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-30 06:02:42.396332: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# ...

# %%
# Replace with the actual paths
source_path = "/content/yolov7/runs"
destination_path = "/content/drive/MyDrive/YOLOv7_Results"

# Copy the entire folder to Google Drive
# !cp -r "{source_path}" "{destination_path}"
